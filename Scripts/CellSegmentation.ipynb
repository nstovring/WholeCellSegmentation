# %%
import tensorflow as tf
from keras_tta import TTA_ModelWrapper
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split


from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Num GPUs Available:  1

# %%
# Set some parameters
im_width = 256
im_height = 256
border = 5
path_train = 'venv/input/train/'
path_test = 'venv/input/test/'

# %%
# Get and resize train images and masks
def get_data(path, train=True):
    ids = next(os.walk(path + "images"))[2]
    X = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
    if train:
        y = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
    print('Getting and resizing images ... ')
    for n, id_ in tqdm_notebook(enumerate(ids), total=len(ids)):
        # Load images
        img = load_img(path + '/images/' + id_, grayscale=True)
        x_img = img_to_array(img)
        x_img = resize(x_img, (256, 256, 1), mode='constant', preserve_range=True)

        # Load masks
        if train:
            mask = img_to_array(load_img(path + '/masks/' + id_, grayscale=True))
            mask = resize(mask, (256, 256, 1), mode='constant', preserve_range=True)

        # Save images
        X[n, ..., 0] = x_img.squeeze() / 255
        if train:
            y[n] = mask / 255
    print('Done!')
    if train:
        return X, y
    else:
        return X

X, y = get_data(path_train, train=True)
# Split train and valid
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.15, random_state=2018)
# Out:
# Getting and resizing images ...
#
# Done!
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# HBox(children=(FloatProgress(value=0.0, max=447.0), HTML(value='')))

# %%
# Check if training data looks all right
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0

fig, ax = plt.subplots(1, 2, figsize=(20, 10))

ax[0].imshow(X_train[ix, ..., 0], cmap='seismic', interpolation='bilinear')
if has_mask:
    ax[0].contour(y_train[ix].squeeze(), colors='k', levels=[0.5])
ax[0].set_title('Seismic')

ax[1].imshow(y_train[ix].squeeze(), interpolation='bilinear', cmap='gray')
ax[1].set_title('Salt');
# Out:
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:9: UserWarning: No contour levels were found within the data range.
#   if __name__ == '__main__':

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)

    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)

    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])

data_gen_args = dict(horizontal_flip=True,
                     vertical_flip=True)
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

seed = 2018
bs = 32

image_generator = image_datagen.flow(X_train, seed=seed, batch_size=bs, shuffle=True)
mask_generator = mask_datagen.flow(y_train, seed=seed, batch_size=bs, shuffle=True)

# Just zip the two generators to get a generator that provides augmented images and masks at the same time
train_generator = zip(image_generator, mask_generator)


model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 16) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 32) 128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 4624        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 32) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 16) 4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 16) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  17          activation_17[0][0]
# ==================================================================================================
# Total params: 2,164,305
# Trainable params: 2,161,361
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
#Now we can train the model.

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]



#results = model.fit(X_train, y_train, batch_size=32, epochs=100, callbacks=callbacks,
                    #validation_data=(X_valid, y_valid))

results = model.fit_generator(train_generator, steps_per_epoch=11, epochs=200, callbacks=callbacks,
                              validation_data=(X_valid, y_valid))


plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
# Out:
# Epoch 1/200
# 11/11 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.8258
# Epoch 00001: val_loss improved from inf to 0.25766, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 459ms/step - loss: 0.1897 - accuracy: 0.8258 - val_loss: 0.2577 - val_accuracy: 0.8761
# Epoch 2/200
# 11/11 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.8334
# Epoch 00002: val_loss improved from 0.25766 to 0.24298, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 458ms/step - loss: 0.1783 - accuracy: 0.8334 - val_loss: 0.2430 - val_accuracy: 0.8761
# Epoch 3/200
# 11/11 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.8339
# Epoch 00003: val_loss improved from 0.24298 to 0.22549, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 452ms/step - loss: 0.1692 - accuracy: 0.8339 - val_loss: 0.2255 - val_accuracy: 0.8761
# Epoch 4/200
# 11/11 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.8316
# Epoch 00004: val_loss improved from 0.22549 to 0.20667, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 446ms/step - loss: 0.1596 - accuracy: 0.8316 - val_loss: 0.2067 - val_accuracy: 0.8761
# Epoch 5/200
# 11/11 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.8224
# Epoch 00005: val_loss improved from 0.20667 to 0.18308, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s
200
# 11/11 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.8235
# Epoch 00021: val_loss did not improve from 0.07320
# 11/11 [==============================] - 5s 442ms/step - loss: 0.0905 - accuracy: 0.8235 - val_loss: 0.0798 - val_accuracy: 0.8761
# Epoch 22/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.8333
# Epoch 00022: val_loss improved from 0.07320 to 0.06839, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0859 - accuracy: 0.8333 - val_loss: 0.0684 - val_accuracy: 0.8761
# Epoch 23/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.8306
# Epoch 00023: val_loss did not improve from 0.06839
# 11/11 [==============================] - 5s 439ms/step - loss: 0.0842 - accuracy: 0.8306 - val_loss: 0.0738 - val_accuracy: 0.8761
# Epoch 24/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.8289
# Epoch 00024: val_loss did not improve from 0.06839
# 11/11 [==============================] - 5s 439ms/step - loss: 0.0840 - accuracy: 0.8289 - val_loss: 0.0691 - val_accuracy: 0.8761
# Epoch 25/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.8317
# Epoch 00025: val_loss improved from 0.06839 to 0.06600, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 454ms/step - loss: 0.0802 - accuracy: 0.8317 - val_loss: 0.0660 - val_accuracy: 0.8761
# Epoch 26/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.8305
# Epoch 00026: val_loss improved from 0.06600 to 0.06568, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 454ms/step - loss: 0.0814 - accuracy: 0.8305 - val_loss: 0.0657 - val_accuracy: 0.8761
# Epoch 27/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.8282
# Epoch 00027: val_loss improved from 0.06568 to 0.06479, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0789 - accuracy: 0.8282 - val_loss: 0.0648 - val_accuracy: 0.8761
# Epoch 28/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.8319
# Epoch 00028: val_loss did not improve from 0.06479
# 11/11 [==============================] - 5s 442ms/step - loss: 0.0772 - accuracy: 0.8319 - val_loss: 0.0651 - val_accuracy: 0.8761
# Epoch 29/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.8335
# Epoch 00029: val_loss improved from 0.06479 to 0.06235, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 449ms/step - loss: 0.0760 - accuracy: 0.8335 - val_loss: 0.0623 - val_accuracy: 0.8761
# Epoch 30/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.8257
# Epoch 00030: val_loss did not improve from 0.06235
# 11/11 [==============================] - 5s 442ms/step - loss: 0.0751 - accuracy: 0.8257 - val_loss: 0.0625 - val_accuracy: 0.8761
# Epoch 31/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.8379
# Epoch 00031: val_loss did not improve from 0.06235
# 11/11 [==============================] - 5s 439ms/step - loss: 0.0733 - accuracy: 0.8379 - val_loss: 0.0635 - val_accuracy: 0.8761
# Epoch 32/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.8250
# Epoch 00032: val_loss improved from 0.06235 to 0.05874, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0732 - accuracy: 0.8250 - val_loss: 0.0587 - val_accuracy: 0.8761
# Epoch 33/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.8260
# Epoch 00033: val_loss improved from 0.05874 to 0.05647, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 447ms/step - loss: 0.0737 - accuracy: 0.8260 - val_loss: 0.0565 - val_accuracy: 0.8761
# Epoch 34/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.8289
# Epoch 00034: val_loss did not improve from 0.05647
# 11/11 [==============================] - 5s 440ms/step - loss: 0.0703 - accuracy: 0.8289 - val_loss: 0.0569 - val_accuracy: 0.8761
# Epoch 35/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.8296
# Epoch 00035: val_loss improved from 0.05647 to 0.05453, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0697 - accuracy: 0.8296 - val_loss: 0.0545 - val_accuracy: 0.8761
# Epoch 36/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.8312
# Epoch 00036: val_loss improved from 0.05453 to 0.05267, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 448ms/step - loss: 0.0697 - accuracy: 0.8312 - val_loss: 0.0527 - val_accuracy: 0.8761
# Epoch 37/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.8308
# Epoch 00037: val_loss improved from 0.05267 to 0.05263, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s
200
# 11/11 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.8330
# Epoch 00054: val_loss improved from 0.04560 to 0.04515, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0607 - accuracy: 0.8330 - val_loss: 0.0451 - val_accuracy: 0.8761
# Epoch 55/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.8266
# Epoch 00055: val_loss improved from 0.04515 to 0.04436, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 452ms/step - loss: 0.0579 - accuracy: 0.8266 - val_loss: 0.0444 - val_accuracy: 0.8761
# Epoch 56/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.8295
# Epoch 00056: val_loss improved from 0.04436 to 0.04405, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0596 - accuracy: 0.8295 - val_loss: 0.0441 - val_accuracy: 0.8761
# Epoch 57/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.8281
# Epoch 00057: val_loss did not improve from 0.04405
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0602 - accuracy: 0.8281 - val_loss: 0.0446 - val_accuracy: 0.8761
# Epoch 58/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.8277
# Epoch 00058: val_loss did not improve from 0.04405
# 11/11 [==============================] - 5s 443ms/step - loss: 0.0585 - accuracy: 0.8277 - val_loss: 0.0454 - val_accuracy: 0.8761
# Epoch 59/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.8321
# Epoch 00059: val_loss improved from 0.04405 to 0.04383, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0579 - accuracy: 0.8321 - val_loss: 0.0438 - val_accuracy: 0.8761
# Epoch 60/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.8300
# Epoch 00060: val_loss improved from 0.04383 to 0.04303, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0574 - accuracy: 0.8300 - val_loss: 0.0430 - val_accuracy: 0.8761
# Epoch 61/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.8327
# Epoch 00061: val_loss did not improve from 0.04303
# 11/11 [==============================] - 5s 451ms/step - loss: 0.0568 - accuracy: 0.8327 - val_loss: 0.0438 - val_accuracy: 0.8761
# Epoch 62/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.8261
# Epoch 00062: val_loss did not improve from 0.04303
# 11/11 [==============================] - 5s 450ms/step - loss: 0.0580 - accuracy: 0.8261 - val_loss: 0.0439 - val_accuracy: 0.8761
# Epoch 63/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.8295
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00063: val_loss improved from 0.04303 to 0.04300, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 454ms/step - loss: 0.0567 - accuracy: 0.8295 - val_loss: 0.0430 - val_accuracy: 0.8761
# Epoch 64/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.8300
# Epoch 00064: val_loss did not improve from 0.04300
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0555 - accuracy: 0.8300 - val_loss: 0.0430 - val_accuracy: 0.8761
# Epoch 65/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.8291
# Epoch 00065: val_loss improved from 0.04300 to 0.04291, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 454ms/step - loss: 0.0574 - accuracy: 0.8291 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 66/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.8306
# Epoch 00066: val_loss improved from 0.04291 to 0.04287, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0551 - accuracy: 0.8306 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 67/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.8344
# Epoch 00067: val_loss improved from 0.04287 to 0.04285, saving model to model-tgs-salt.h5
# 11/11 [==============================] - 5s 453ms/step - loss: 0.0573 - accuracy: 0.8344 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 68/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.8293
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00068: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0563 - accuracy: 0.8293 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 69/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.8258
# Epoch 00069: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0561 - accuracy: 0.8258 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 70/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.8376
# Epoch 00070: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0543 - accuracy: 0.8376 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 71/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.8228
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00071: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 444ms/step - loss: 0.0585 - accuracy: 0.8228 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 72/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.8325
# Epoch 00072: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0554 - accuracy: 0.8325 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 73/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.8275
# Epoch 00073: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 451ms/step - loss: 0.0568 - accuracy: 0.8275 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 74/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.8358
# Epoch 00074: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 451ms/step - loss: 0.0543 - accuracy: 0.8358 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 75/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.8272
# Epoch 00075: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0583 - accuracy: 0.8272 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 76/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.8276
# Epoch 00076: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 445ms/step - loss: 0.0562 - accuracy: 0.8276 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 77/200
# 11/11 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.8324
# Epoch 00077: val_loss did not improve from 0.04285
# 11/11 [==============================] - 5s 443ms/step - loss: 0.0537 - accuracy: 0.8324 - val_loss: 0.0429 - val_accuracy: 0.8761
# Epoch 00077: early stopping

# %%
# Load best model
model.load_weights('model-tgs-salt.h5')

# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_valid, y_valid, verbose=1)

# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0429 - accuracy: 0.8761
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_predict_batch_end` time: 0.1240s). Check your callbacks.
# 12/12 [==============================] - 2s 128ms/step
# WARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0050s vs `on_predict_batch_end` time: 0.1310s). Check your callbacks.
# 3/3 [==============================] - 0s 94ms/step

# %%
from keras_tta import TTA_ModelWrapper

tta_model = TTA_ModelWrapper(model)
preds_val_tta = tta_model.predict(X_valid)
preds_train_tta = tta_model.predict(X_train)

# Threshold predictions
preds_train_t = (preds_train > 0.2).astype(np.uint8)
preds_val_t = (preds_val > 0.2).astype(np.uint8)



def plot_sample(X, y, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0])
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Image')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Cells')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Cells Predicted')

    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Cells Predicted binary');

def plot_sample(X, y, preds, preds_tta, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 5, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Seismic')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Salt')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Salt Predicted')

    ax[3].imshow(preds_tta[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Salt Predicted TTA')

    ax[4].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[4].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[4].set_title('Salt Predicted binary');

# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_tta, preds_train_tta>0.1)

# Check if valid data looks all right
plot_sample(X_valid, y_valid, preds_val, preds_val_tta, preds_val_tta>0.1)

# Check if training data looks all right
#plot_sample(X_train, y_train, preds_train, preds_train_t, ix=10)
# Check if valid data looks all right
#plot_sample(X_valid, y_valid, preds_val, preds_val_t, ix=10)
# Out:
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:47: UserWarning: No contour levels were found within the data range.
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:55: UserWarning: No contour levels were found within the data range.
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:60: UserWarning: No contour levels were found within the data range.
# c:\users\admin\pycharmprojects\unet\venv\lib\site-packages\ipykernel_launcher.py:65: UserWarning: No contour levels were found within the data range.
